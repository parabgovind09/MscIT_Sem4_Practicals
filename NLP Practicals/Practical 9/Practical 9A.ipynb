# %%
# Practical 9 :- Handling Stopwords

# %%
# Practical 9A :- Using NLTK adding or removing stopwords in NLTK's default stopword lists.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: joblib in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: click in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\minal\appdata\local\programs\python\python39\lib\site-packages (from tqdm->nltk) (0.4.6)
# WARNING: You are using pip version 20.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\users\minal\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Minal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Minal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
text = "Dog is a pet animal. It is the oldest friend of human beings. It watches our house. It is very faithful animal and never left his master. It is used by police to fight crime. Sheep- rearers also use them. Thus it is useful for us in many ways. Cow is important cattle. It is reared all over the world for milk. In India it is a holy animal. Many people worship it. In rural area it fulfills the need of protein. Its waste is also used for making dung. We must protect it as a valuable asset."

# %%
print(text)
# Out:
# Dog is a pet animal. It is the oldest friend of human beings. It watches our house. It is very faithful animal and never left his master. It is used by police to fight crime. Sheep- rearers also use them. Thus it is useful for us in many ways. Cow is important cattle. It is reared all over the world for milk. In India it is a holy animal. Many people worship it. In rural area it fulfills the need of protein. Its waste is also used for making dung. We must protect it as a valuable asset.

# %%
tokens = word_tokenize(text)

# %%
tokens
# Out:
# ['Dog',
#  'is',
#  'a',
#  'pet',
#  'animal',
#  '.',
#  'It',
#  'is',
#  'the',
#  'oldest',
#  'friend',
#  'of',
#  'human',
#  'beings',
#  '.',
#  'It',
#  'watches',
#  'our',
#  'house',
#  '.',
#  'It',
#  'is',
#  'very',
#  'faithful',
#  'animal',
#  'and',
#  'never',
#  'left',
#  'his',
#  'master',
#  '.',
#  'It',
#  'is',
#  'used',
#  'by',
#  'police',
#  'to',
#  'fight',
#  'crime',
#  '.',
#  'Sheep-',
#  'rearers',
#  'also',
#  'use',
#  'them',
#  '.',
#  'Thus',
#  'it',
#  'is',
#  'useful',
#  'for',
#  'us',
#  'in',
#  'many',
#  'ways',
#  '.',
#  'Cow',
#  'is',
#  'important',
#  'cattle',
#  '.',
#  'It',
#  'is',
#  'reared',
#  'all',
#  'over',
#  'the',
#  'world',
#  'for',
#  'milk',
#  '.',
#  'In',
#  'India',
#  'it',
#  'is',
#  'a',
#  'holy',
#  'animal',
#  '.',
#  'Many',
#  'people',
#  'worship',
#  'it',
#  '.',
#  'In',
#  'rural',
#  'area',
#  'it',
#  'fulfills',
#  'the',
#  'need',
#  'of',
#  'protein',
#  '.',
#  'Its',
#  'waste',
#  'is',
#  'also',
#  'used',
#  'for',
#  'making',
#  'dung',
#  '.',
#  'We',
#  'must',
#  'protect',
#  'it',
#  'as',
#  'a',
#  'valuable',
#  'asset',
#  '.']

# %%
token_without_stopword = [word for word in tokens if word not in stopwords.words()]

# %%
token_without_stopword
# Out:
# ['Dog',
#  'animal',
#  '.',
#  'It',
#  'oldest',
#  'friend',
#  'human',
#  'beings',
#  '.',
#  'It',
#  'watches',
#  'house',
#  '.',
#  'It',
#  'faithful',
#  'animal',
#  'left',
#  'master',
#  '.',
#  'It',
#  'police',
#  'fight',
#  'crime',
#  '.',
#  'Sheep-',
#  'rearers',
#  '.',
#  'Thus',
#  'ways',
#  '.',
#  'Cow',
#  'important',
#  'cattle',
#  '.',
#  'It',
#  'reared',
#  'world',
#  'milk',
#  '.',
#  'In',
#  'India',
#  'holy',
#  'animal',
#  '.',
#  'Many',
#  'worship',
#  '.',
#  'In',
#  'rural',
#  'area',
#  'fulfills',
#  'protein',
#  '.',
#  'Its',
#  'waste',
#  'making',
#  'dung',
#  '.',
#  'We',
#  'protect',
#  'valuable',
#  'asset',
#  '.']

# %%
all_stopwords = stopwords.words("english")

# %%
all_stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
all_stopwords.append(".")

# %%
tokens = word_tokenize(text)

# %%
tokens
# Out:
# ['Dog',
#  'is',
#  'a',
#  'pet',
#  'animal',
#  '.',
#  'It',
#  'is',
#  'the',
#  'oldest',
#  'friend',
#  'of',
#  'human',
#  'beings',
#  '.',
#  'It',
#  'watches',
#  'our',
#  'house',
#  '.',
#  'It',
#  'is',
#  'very',
#  'faithful',
#  'animal',
#  'and',
#  'never',
#  'left',
#  'his',
#  'master',
#  '.',
#  'It',
#  'is',
#  'used',
#  'by',
#  'police',
#  'to',
#  'fight',
#  'crime',
#  '.',
#  'Sheep-',
#  'rearers',
#  'also',
#  'use',
#  'them',
#  '.',
#  'Thus',
#  'it',
#  'is',
#  'useful',
#  'for',
#  'us',
#  'in',
#  'many',
#  'ways',
#  '.',
#  'Cow',
#  'is',
#  'important',
#  'cattle',
#  '.',
#  'It',
#  'is',
#  'reared',
#  'all',
#  'over',
#  'the',
#  'world',
#  'for',
#  'milk',
#  '.',
#  'In',
#  'India',
#  'it',
#  'is',
#  'a',
#  'holy',
#  'animal',
#  '.',
#  'Many',
#  'people',
#  'worship',
#  'it',
#  '.',
#  'In',
#  'rural',
#  'area',
#  'it',
#  'fulfills',
#  'the',
#  'need',
#  'of',
#  'protein',
#  '.',
#  'Its',
#  'waste',
#  'is',
#  'also',
#  'used',
#  'for',
#  'making',
#  'dung',
#  '.',
#  'We',
#  'must',
#  'protect',
#  'it',
#  'as',
#  'a',
#  'valuable',
#  'asset',
#  '.']

# %%
token_without_stopword2 = [word for word in tokens if word not in all_stopwords]

# %%
token_without_stopword2
# Out:
# ['Dog',
#  'pet',
#  'animal',
#  'It',
#  'oldest',
#  'friend',
#  'human',
#  'beings',
#  'It',
#  'watches',
#  'house',
#  'It',
#  'faithful',
#  'animal',
#  'never',
#  'left',
#  'master',
#  'It',
#  'used',
#  'police',
#  'fight',
#  'crime',
#  'Sheep-',
#  'rearers',
#  'also',
#  'use',
#  'Thus',
#  'useful',
#  'us',
#  'many',
#  'ways',
#  'Cow',
#  'important',
#  'cattle',
#  'It',
#  'reared',
#  'world',
#  'milk',
#  'In',
#  'India',
#  'holy',
#  'animal',
#  'Many',
#  'people',
#  'worship',
#  'In',
#  'rural',
#  'area',
#  'fulfills',
#  'need',
#  'protein',
#  'Its',
#  'waste',
#  'also',
#  'used',
#  'making',
#  'dung',
#  'We',
#  'must',
#  'protect',
#  'valuable',
#  'asset']

# %%
all_stopwords.remove("is")

# %%
token = word_tokenize(text)

# %%
token
# Out:
# ['Dog',
#  'is',
#  'a',
#  'pet',
#  'animal',
#  '.',
#  'It',
#  'is',
#  'the',
#  'oldest',
#  'friend',
#  'of',
#  'human',
#  'beings',
#  '.',
#  'It',
#  'watches',
#  'our',
#  'house',
#  '.',
#  'It',
#  'is',
#  'very',
#  'faithful',
#  'animal',
#  'and',
#  'never',
#  'left',
#  'his',
#  'master',
#  '.',
#  'It',
#  'is',
#  'used',
#  'by',
#  'police',
#  'to',
#  'fight',
#  'crime',
#  '.',
#  'Sheep-',
#  'rearers',
#  'also',
#  'use',
#  'them',
#  '.',
#  'Thus',
#  'it',
#  'is',
#  'useful',
#  'for',
#  'us',
#  'in',
#  'many',
#  'ways',
#  '.',
#  'Cow',
#  'is',
#  'important',
#  'cattle',
#  '.',
#  'It',
#  'is',
#  'reared',
#  'all',
#  'over',
#  'the',
#  'world',
#  'for',
#  'milk',
#  '.',
#  'In',
#  'India',
#  'it',
#  'is',
#  'a',
#  'holy',
#  'animal',
#  '.',
#  'Many',
#  'people',
#  'worship',
#  'it',
#  '.',
#  'In',
#  'rural',
#  'area',
#  'it',
#  'fulfills',
#  'the',
#  'need',
#  'of',
#  'protein',
#  '.',
#  'Its',
#  'waste',
#  'is',
#  'also',
#  'used',
#  'for',
#  'making',
#  'dung',
#  '.',
#  'We',
#  'must',
#  'protect',
#  'it',
#  'as',
#  'a',
#  'valuable',
#  'asset',
#  '.']

# %%
token_without_stopword3 = [word for word in token if word not in all_stopwords]

# %%
token_without_stopword3
# Out:
# ['Dog',
#  'is',
#  'pet',
#  'animal',
#  'It',
#  'is',
#  'oldest',
#  'friend',
#  'human',
#  'beings',
#  'It',
#  'watches',
#  'house',
#  'It',
#  'is',
#  'faithful',
#  'animal',
#  'never',
#  'left',
#  'master',
#  'It',
#  'is',
#  'used',
#  'police',
#  'fight',
#  'crime',
#  'Sheep-',
#  'rearers',
#  'also',
#  'use',
#  'Thus',
#  'is',
#  'useful',
#  'us',
#  'many',
#  'ways',
#  'Cow',
#  'is',
#  'important',
#  'cattle',
#  'It',
#  'is',
#  'reared',
#  'world',
#  'milk',
#  'In',
#  'India',
#  'is',
#  'holy',
#  'animal',
#  'Many',
#  'people',
#  'worship',
#  'In',
#  'rural',
#  'area',
#  'fulfills',
#  'need',
#  'protein',
#  'Its',
#  'waste',
#  'is',
#  'also',
#  'used',
#  'making',
#  'dung',
#  'We',
#  'must',
#  'protect',
#  'valuable',
#  'asset']
